# %%
import requests
from bs4 import BeautifulSoup
import re

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
URL = 'https://github.com/geoschem/cloud_GC/issues/15'

page = requests.get(URL)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
#print(soup.prettify())

# %%
class_to_search = 'd-block comment-body markdown-body js-comment-body'  # only the content

all_comments = soup.find_all('td', class_=class_to_search)[1:]
len(all_comments)
# Out:
# 23

# %%
all_comments[0]
# Out:
# <td class="d-block comment-body markdown-body js-comment-body">
# <p>Here's a sample reply:</p>
# <p>Background: XX University, XX department, Graduate Student<br/>
# GEOS-Chem experience: X years<br/>
# Step 1: X minutes<br/>
# Step 2: X minutes<br/>
# Step 3: X minutes<br/>
# Step 4: X minutes<br/>
# General feedback: None</p>
# </td>

# %%
items = ['GEOS-Chem experience: ', 'Step 1: ', 'Step 2: ', 'Step 3: ', 'Step 4: ']
re_list = [re.compile(txt) for txt in items]

n_comments = len(all_comments)
n_items = len(items)

# %%
result = np.empty([n_comments-1, n_items], dtype='object')

for i in range(n_comments-1):
    for j in range(n_items):
        # 
        try:
            text = all_comments[i+1].find(text=re_list[j])
            text = text.strip().replace(items[j], '')
            # text = text.split()[0]
            result[i, j] = text
        except:
            print('failed:', i, j)

# %%
df = pd.DataFrame(result, columns=[item[:-2] for item in items])
df
# Out:
#         GEOS-Chem experience  \
# 0                    4 years
# 1                     1 year
# 2                    7 years
# 3                  20+ years
# 4                    5 years
# 5                   9 months
# 6   Ran for undergrad thesis
# 7                    6 years
# 8                    7 years
# 9                       None
# 10                 0.5 years
# 11                   4 years
# 12                    1 year
# 13                   0 years
# 14                   0 years
# 15                   0 years
# 16                   0 years
# 17                   0 years
# 18                    1 year
# 19                   7 years
# 20                   2 years
# 21                   0 years
#
#                                                Step 1  \
# 0                                           6 minutes
# 1                                          10 minutes
# 2                                           5 minutes
# 3                                           5 minutes
# 4                                           4 minutes
# 5                                          10 minutes
# 6                                           5 minutes
# 7                                          10 minutes
# 8                                           7 minutes
# 9                                           5 minutes
# 10                                          5 minutes
# 11                                          8 minutes
# 12                                          8 minutes
# 13                                          8 minutes
# 14                                          9 minutes
# 15                                          5 minutes
# 16                                          8 minutes
# 17  120 minutes (a lot of time waste for phone ver...
# 18                                         10 minutes
# 19                                             10 min
# 20  20 minutes (lots of time wasting for account v...
# 21                                          8 minutes
#
#                                                Step 2  \
# 0                                           6 minutes
# 1                                         1.5 minutes
# 2   6 minutes, wait 1 hour for account verificatio...
# 3                                           5 minutes
# 4        5 minutes, wait ~ half hour for verification
# 5                                           7 minutes
# 6                                           6 minutes
# 7   30 minutes (had to wait for account verification)
# 8   5 minutes (takes ~ 1hour for account verificat...
# 9                                           6 minutes
# 10      5 minutes (account verification takes 15 min)
# 11                                          9 minutes
# 12  5 minutes (not including 10 mins waiting time ...
# 13                                         13 minutes
# 14                                         18 minutes
# 15  5 minutes (waited for another 20 min to verify...
# 16          12 minutes (15 min. for AWS verification)
# 17  12 minutes (another 10 minutes for AWS verific...
# 18                                          5 minutes
# 19                                              3 min
# 20                                         10 minutes
# 21  7 minutes plus 13 minutes for acount verification
#
#                                                Step 3  \
# 0   5 minutes (not including wait time for GEOS-Ch...
# 1                                           3 minutes
# 2                                           7 minutes
# 3                                           5 minutes
# 4                                           7 minutes
# 5                                           3 minutes
# 6                                           4 minutes
# 7                                           5 minutes
# 8                                           3 minutes
# 9                                           4 minutes
# 10  3 minutes (takes 15 min to install Git-BASH, b...
# 11                                          7 minutes
# 12                                         10 minutes
# 13                                         14 minutes
# 14                                         50 minutes
# 15                                         15 minutes
# 16                                          4 minutes
# 17    18 minutes  (another 10 minutes for simulation)
# 18  15 minutes (there was considerable SSH lag fro...
# 19                                              9 min
# 20                                         10 minutes
# 21        5 minutes plus 8 min to complete simulation
#
#                                                Step 4
# 0                                           9 minutes
# 1                                          13 minutes
# 2                                          34 minutes
# 3                                          16 minutes
# 4   8 minutes, a little bit confusion in activate ...
# 5                                           2 minutes
# 6                                           6 minutes
# 7                                          15 minutes
# 8                                           8 minutes
# 9                                           6 minutes
# 10                                          3 minutes
# 11                                          6 minutes
# 12                                          7 minutes
# 13  20 minutes (lots of time wasting involved though)
# 14                                         15 minutes
# 15                                         20 minutes
# 16                                          7 minutes
# 17  12 minutes (just analyzed with python, not inc...
# 18    8 minutes (I used the pre-provided output file)
# 19                                              3 min
# 20                                         15 minutes
# 21  9 minutes plus 3 minutes to open jupyter noteb...

# %%
selected_idx = list(range(14)) + [19]  # only choose people in Harvard ACMG 
df = df.iloc[selected_idx]
df
# Out:
#         GEOS-Chem experience      Step 1  \
# 0                    4 years   6 minutes
# 1                     1 year  10 minutes
# 2                    7 years   5 minutes
# 3                  20+ years   5 minutes
# 4                    5 years   4 minutes
# 5                   9 months  10 minutes
# 6   Ran for undergrad thesis   5 minutes
# 7                    6 years  10 minutes
# 8                    7 years   7 minutes
# 9                       None   5 minutes
# 10                 0.5 years   5 minutes
# 11                   4 years   8 minutes
# 12                    1 year   8 minutes
# 13                   0 years   8 minutes
# 19                   7 years      10 min
#
#                                                Step 2  \
# 0                                           6 minutes
# 1                                         1.5 minutes
# 2   6 minutes, wait 1 hour for account verificatio...
# 3                                           5 minutes
# 4        5 minutes, wait ~ half hour for verification
# 5                                           7 minutes
# 6                                           6 minutes
# 7   30 minutes (had to wait for account verification)
# 8   5 minutes (takes ~ 1hour for account verificat...
# 9                                           6 minutes
# 10      5 minutes (account verification takes 15 min)
# 11                                          9 minutes
# 12  5 minutes (not including 10 mins waiting time ...
# 13                                         13 minutes
# 19                                              3 min
#
#                                                Step 3  \
# 0   5 minutes (not including wait time for GEOS-Ch...
# 1                                           3 minutes
# 2                                           7 minutes
# 3                                           5 minutes
# 4                                           7 minutes
# 5                                           3 minutes
# 6                                           4 minutes
# 7                                           5 minutes
# 8                                           3 minutes
# 9                                           4 minutes
# 10  3 minutes (takes 15 min to install Git-BASH, b...
# 11                                          7 minutes
# 12                                         10 minutes
# 13                                         14 minutes
# 19                                              9 min
#
#                                                Step 4
# 0                                           9 minutes
# 1                                          13 minutes
# 2                                          34 minutes
# 3                                          16 minutes
# 4   8 minutes, a little bit confusion in activate ...
# 5                                           2 minutes
# 6                                           6 minutes
# 7                                          15 minutes
# 8                                           8 minutes
# 9                                           6 minutes
# 10                                          3 minutes
# 11                                          6 minutes
# 12                                          7 minutes
# 13  20 minutes (lots of time wasting involved though)
# 19                                              3 min

# %%
df_num = df.drop('GEOS-Chem experience', axis=1).applymap(lambda s: float(s.split()[0]))
df_num['total'] = df_num.sum(axis=1)
df_num
# Out:
#     Step 1  Step 2  Step 3  Step 4  total
# 0      6.0     6.0     5.0     9.0   26.0
# 1     10.0     1.5     3.0    13.0   27.5
# 2      5.0     6.0     7.0    34.0   52.0
# 3      5.0     5.0     5.0    16.0   31.0
# 4      4.0     5.0     7.0     8.0   24.0
# 5     10.0     7.0     3.0     2.0   22.0
# 6      5.0     6.0     4.0     6.0   21.0
# 7     10.0    30.0     5.0    15.0   60.0
# 8      7.0     5.0     3.0     8.0   23.0
# 9      5.0     6.0     4.0     6.0   21.0
# 10     5.0     5.0     3.0     3.0   16.0
# 11     8.0     9.0     7.0     6.0   30.0
# 12     8.0     5.0    10.0     7.0   30.0
# 13     8.0    13.0    14.0    20.0   55.0
# 19    10.0     3.0     9.0     3.0   25.0

# %%
xx = np.ones(df_num.shape[0])

for i in range(4):
    plt.scatter(xx*(i+1), df_num.iloc[:,i], alpha=0.4)
    
plt.xticks([1,2,3,4], items[1:])
# Out:
# ([<matplotlib.axis.XTick at 0x123719f28>,
#   <matplotlib.axis.XTick at 0x123719860>,
#   <matplotlib.axis.XTick at 0x123719588>,
#   <matplotlib.axis.XTick at 0x123761f28>],
#  <a list of 4 Text xticklabel objects>)

# %%
xx = np.ones(df_num.shape[0])

for i in range(4):
    plt.scatter(df_num.iloc[:,i], xx*(4-i)+(np.random.rand(df_num.shape[0])-0.5)*0.2, alpha=0.4)
    
plt.yticks([1,2,3,4], ['get AWS account', 'launch server', 'connect to server \n and run GEOS-Chem', 
                       'use Python/Jupyter \n to plot output data'][::-1])
plt.xlabel('minutes')
plt.title('time spent on each step for a new user')
plt.tight_layout()
#plt.savefig('user-survey.png', dpi=200)

# %%
df_for_sns = df_num.iloc[:,0:4].stack().reset_index().rename({'level_0': 'sample', 'level_1': 'step', 0: 'minutes'}, axis='columns')
df_for_sns.head()
# Out:
#    sample    step  minutes
# 0       0  Step 1      6.0
# 1       0  Step 2      6.0
# 2       0  Step 3      5.0
# 3       0  Step 4      9.0
# 4       1  Step 1     10.0

# %%
import seaborn as sns

sns.swarmplot(x='minutes', y='step', data=df_for_sns, s=6)

plt.yticks(range(4), ['Sigining up for \n AWS account', 
                      'Launch server \n (EC2 instance)', 
                      'Connect to server \n and start simulation', 
                      'Plot output data \n in Jupyter notebook'])
plt.ylabel(' ')

plt.title('Time to finish demo workflow for a new user')
plt.tight_layout()
plt.savefig('user-survey.png', dpi=300)
